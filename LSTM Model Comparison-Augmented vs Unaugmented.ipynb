# %%
import re
import os
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.models import Sequential, Model
from keras.layers import Dense,Dropout, Embedding, LSTM, SpatialDropout1D, Input, Concatenate, Bidirectional
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping, LearningRateScheduler, TensorBoard
from tensorflow.keras import layers
from tensorflow.keras.optimizers.schedules import PolynomialDecay
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("/kaggle/input/processed-sub/processed_all_text.csv")

# %%
df.head(3)
# Out:
#        id  num_comments  score  upvote_ratio  \
# 0  x2wyl4           1.0    1.0           1.0
# 1  x2uv4c           1.0    1.0           1.0
# 2  x2pn4w           1.0    1.0           1.0
#
#                                             all_text  hour  Class  body_len
# 0  I can't even eat chocolate without thinking ab...    10      1       356
# 1  How do I know he's really changing? I think th...     8      1       380
# 2  Just got my 5th NFA 😭 This is more of a rant t...     4      1       732

# %%
df.Class.value_counts()
# Out:
# 0    233426
# 1     10276
# Name: Class, dtype: int64

# %%
sample_text = df['all_text'].iloc[11]
sample_text
# Out:
# "ladies please take warning and stay aware from him https://www.tiktok.com/t/ZTRPL4whN/\n\nI'm trying to spread awareness to all so u don't go through the physical and emotional abuse that he put me through.... ais there any advice to help recover?"

# %%
augmenter = aug.ContextualWordEmbsAug(model_path='bert-base-uncased', 
                                      action="insert", device='cuda')

# %%
augmented_sample_text = augmenter.augment(sample_text)
augmented_sample_text
# Out:
# ["ladies please take warning and stay aware only from him https : / / www. tiktok. at com / [UNK] t / the ztrpl4whn / [UNK] i'm trying to spread awareness to all so hope u don't just go through the physical and emotional abuse spells that he put his me through.... ais there any advice here to help recover?"]

# %%
for i in range(5):
    print(augmenter.augment(sample_text))
# Out:
# ["ladies first please just take a warning and stay aware email from him https : / / www. david tiktok. com / t / ztrpl4whn / i'm trying harder to spread awareness to all youth so u will don't go through the physical and emotional abuse that he put me through.... ais there iss any advice enough to help recover?"]
# ["now ladies please take warning and stay more aware and from him https : / / www. tiktok. com / t / ztrpl4whn / i'm trying to spread awareness to them all so u please don't go rushing through about the terrible physical and and emotional abuse that man he put me through.... ais there any advice to help recover?"]
# ["ladies please take warning and stay quite aware from watching him https : / / dot www. tiktok. com / t / ztrpl4whn / but i'm trying to spread awareness to all children so u don't go going through the physical and emotional anxiety abuse that he put me through.... to ais there is any additional advice to help recover?"]
# ["so ladies please all take your warning and stay aware from him https : / / now www. big tiktok. com / t / ztrpl4whn / i'm trying to spread personal awareness to all so much u don't instantly go crashing through the physical and emotional abuse that he just put me through.... ais there any advice to help recover?"]
# ["ladies please take warning items and stay aware from him through https : / / www. tiktok. com / buy t / on ztrpl4whn / a i'm only trying to spread awareness to men all so u ya don'won t go through the physical and emotional abuse that he put me through.... ais there any advice offered to help recover?"]

# %%
df['Class'].value_counts()
# Out:
# 0    233426
# 1     10276
# Name: Class, dtype: int64

# %%
def augmentMyData(df, augmenter, repetitions=1, samples=40000):
    augmented_texts = []
    # select only the minority class samples
    dv_df = df[df['Class'] == 1].reset_index(drop=True) # removes unecessary index column
    for i in tqdm(np.random.randint(0, len(dv_df), samples)):
        # generating 'n_samples' augmented texts
        for _ in range(repetitions):
            augmented_text = augmenter.augment(dv_df['all_text'].iloc[i])
            augmented_texts.append(augmented_text)
    
    data = {
        'Class': 1,
        'all_text': augmented_texts
    }
    aug_df = pd.DataFrame(data)
    df = shuffle(df.append(aug_df).reset_index(drop=True))
    return df

# %%
new_df = df[['Class', 'all_text']]
new_df.head()
# Out:
#    Class                                           all_text
# 0      1  I can't even eat chocolate without thinking ab...
# 1      1  How do I know he's really changing? I think th...
# 2      1  Just got my 5th NFA 😭 This is more of a rant t...
# 3      1  Can't find the energy to leave Hi, I have been...
# 4      1  Am I really at a point where I should avoid do...

# %%
aug_df = augmentMyData(new_df, augmenter, samples=60000)

# %%
aug_df.to_csv('aug_df.csv', index=False)

# %%
aug_df= pd.read_csv("/kaggle/input/augmented-df/aug_df.csv")
aug_df.head()
# Out:
#    Class                                           all_text
# 0      1  ['surviving the holidays i left my abusive hus...
# 1      0  How do I (22M) tell the girl I like (20F) the ...
# 2      0       What do you call an angry German? Sauerkraut
# 3      1  ['please help. hello. i am a teen. my brothers...
# 4      0  My local supermarket was selling a pallet of 2...

# %%
aug_df.Class.value_counts()
# Out:
# 0    233426
# 1     70276
# Name: Class, dtype: int64

# %%
print("Original: ", df.shape)
print("Augmented: ", aug_df.shape)
# Out:
# Original:  (243702, 8)
# Augmented:  (303702, 2)

# %%
train_data, val_data= train_test_split(df, test_size=0.6, random_state=25)
val_data, test_data= train_test_split(val_data, test_size=0.5, random_state=25)
train_data.shape,  val_data.shape, test_data.shape
# Out:
# ((97480, 8), (73111, 8), (73111, 8))

# %%
train_data.Class.value_counts()
# Out:
# 0    93335
# 1     4145
# Name: Class, dtype: int64

# %%
aug_train_data, _ = train_test_split(aug_df, test_size=0.6, random_state=25)
aug_train_data.shape
# Out:
# (121480, 2)

# %%
aug_train_data.Class.value_counts()
# Out:
# 0    93329
# 1    28151
# Name: Class, dtype: int64

# %%
MAX_NB_WORDS = 50000
MAX_SEQUENCE_LENGTH =500
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(aug_df['all_text'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 161644 unique tokens.

# %%
X_train=train_data['all_text']
aug_X_train=aug_train_data['all_text']
y_train = train_data.Class
aug_y_train=aug_train_data.Class

X_val=val_data['all_text']
y_val = val_data.Class

X_test=test_data['all_text']
y_test = test_data.Class
X_train.shape, y_train.shape, aug_X_train.shape, aug_y_train.shape
# Out:
# ((97480,), (97480,), (121480,), (121480,))

# %%
X_val.shape,X_test.shape, y_val.shape,y_test.shape
# Out:
# ((73111,), (73111,), (73111,), (73111,))

# %%
#create sequences for vinila LSTM model
X_vect_train = tokenizer.texts_to_sequences(X_train.values)
X_vect_train = pad_sequences(X_vect_train, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of X_train data tensor:', X_vect_train.shape)

aug_X_vect_train = tokenizer.texts_to_sequences(aug_X_train.values)
aug_X_vect_train = pad_sequences(aug_X_vect_train, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of aug_X_train data tensor:', aug_X_vect_train.shape)

X_vect_val = tokenizer.texts_to_sequences(X_val.values)
X_vect_val = pad_sequences(X_vect_val, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of X_val data tensor:', X_vect_val.shape)

X_vect_test = tokenizer.texts_to_sequences(X_test.values)
X_vect_test = pad_sequences(X_vect_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of X_test data tensor:', X_vect_test.shape)
# Out:
# Shape of X_train data tensor: (97480, 500)
# Shape of aug_X_train data tensor: (121480, 500)
# Shape of X_val data tensor: (73111, 500)
# Shape of X_test data tensor: (73111, 500)

# %%
METRICS = [
    keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

CALLBACKS=[EarlyStopping(monitor='val_prc', verbose=1,patience=5, mode='max',restore_best_weights=True)]

EPOCHS = 20

# %% [markdown]
# ### 1. unaugmented dataset

# %%
modelV0 = Sequential()
modelV0.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X_vect_train.shape[1]))
modelV0.add(SpatialDropout1D(0.6))
modelV0.add(LSTM(64, dropout=0.6, recurrent_dropout=0))
modelV0.add(Dense(1, activation='sigmoid'))
modelV0.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=METRICS)
print(modelV0.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 100)          5000000
#
#  spatial_dropout1d (SpatialD  (None, 500, 100)         0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 5,042,305
# Trainable params: 5,042,305
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
historyV0 = modelV0.fit(
    X_vect_train, 
    y_train,
    batch_size=32,
    epochs=EPOCHS,
    validation_data=(X_vect_val, y_val),
    callbacks=CALLBACKS)
# Out:
# Epoch 1/20
# 3047/3047 [==============================] - 218s 68ms/step - loss: 0.1593 - tp: 201.0000 - fp: 151.0000 - tn: 93184.0000 - fn: 3944.0000 - accuracy: 0.9580 - precision: 0.5710 - recall: 0.0485 - auc: 0.7068 - prc: 0.1699 - val_loss: 0.0969 - val_tp: 1548.0000 - val_fp: 660.0000 - val_tn: 69418.0000 - val_fn: 1485.0000 - val_accuracy: 0.9707 - val_precision: 0.7011 - val_recall: 0.5104 - val_auc: 0.9146 - val_prc: 0.5474
# Epoch 2/20
# 3047/3047 [==============================] - 97s 32ms/step - loss: 0.1026 - tp: 1827.0000 - fp: 844.0000 - tn: 92491.0000 - fn: 2318.0000 - accuracy: 0.9676 - precision: 0.6840 - recall: 0.4408 - auc: 0.9004 - prc: 0.5378 - val_loss: 0.1121 - val_tp: 710.0000 - val_fp: 181.0000 - val_tn: 69897.0000 - val_fn: 2323.0000 - val_accuracy: 0.9658 - val_precision: 0.7969 - val_recall: 0.2341 - val_auc: 0.8831 - val_prc: 0.5831
# Epoch 3/20
# 3047/3047 [==============================] - 91s 30ms/step - loss: 0.0958 - tp: 2054.0000 - fp: 862.0000 - tn: 92473.0000 - fn: 2091.0000 - accuracy: 0.9697 - precision: 0.7044 - recall: 0.4955 - auc: 0.9105 - prc: 0.5810 - val_loss: 0.0949 - val_tp: 1905.0000 - val_fp: 752.0000 - val_tn: 69326.0000 - val_fn: 1128.0000 - val_accuracy: 0.9743 - val_precision: 0.7170 - val_recall: 0.6281 - val_auc: 0.8942 - val_prc: 0.5952
# Epoch 4/20
# 3047/3047 [==============================] - 86s 28ms/step - loss: 0.0931 - tp: 2177.0000 - fp: 900.0000 - tn: 92435.0000 - fn: 1968.0000 - accuracy: 0.9706 - precision: 0.7075 - recall: 0.5252 - auc: 0.9151 - prc: 0.5953 - val_loss: 0.0832 - val_tp: 1929.0000 - val_fp: 607.0000 - val_tn: 69471.0000 - val_fn: 1104.0000 - val_accuracy: 0.9766 - val_precision: 0.7606 - val_recall: 0.6360 - val_auc: 0.9131 - val_prc: 0.6753
# Epoch 5/20
# 3047/3047 [==============================] - 88s 29ms/step - loss: 0.0902 - tp: 2217.0000 - fp: 821.0000 - tn: 92514.0000 - fn: 1928.0000 - accuracy: 0.9718 - precision: 0.7298 - recall: 0.5349 - auc: 0.9250 - prc: 0.6233 - val_loss: 0.0874 - val_tp: 1888.0000 - val_fp: 652.0000 - val_tn: 69426.0000 - val_fn: 1145.0000 - val_accuracy: 0.9754 - val_precision: 0.7433 - val_recall: 0.6225 - val_auc: 0.9231 - val_prc: 0.6388
# Epoch 6/20
# 3047/3047 [==============================] - 84s 28ms/step - loss: 0.0892 - tp: 2235.0000 - fp: 815.0000 - tn: 92520.0000 - fn: 1910.0000 - accuracy: 0.9720 - precision: 0.7328 - recall: 0.5392 - auc: 0.9273 - prc: 0.6292 - val_loss: 0.0908 - val_tp: 1783.0000 - val_fp: 446.0000 - val_tn: 69632.0000 - val_fn: 1250.0000 - val_accuracy: 0.9768 - val_precision: 0.7999 - val_recall: 0.5879 - val_auc: 0.9036 - val_prc: 0.6599
# Epoch 7/20
# 3047/3047 [==============================] - 82s 27ms/step - loss: 0.0898 - tp: 2189.0000 - fp: 802.0000 - tn: 92533.0000 - fn: 1956.0000 - accuracy: 0.9717 - precision: 0.7319 - recall: 0.5281 - auc: 0.9254 - prc: 0.6306 - val_loss: 0.0863 - val_tp: 1626.0000 - val_fp: 258.0000 - val_tn: 69820.0000 - val_fn: 1407.0000 - val_accuracy: 0.9772 - val_precision: 0.8631 - val_recall: 0.5361 - val_auc: 0.9082 - val_prc: 0.6987
# Epoch 8/20
# 3047/3047 [==============================] - 84s 28ms/step - loss: 0.0884 - tp: 2300.0000 - fp: 806.0000 - tn: 92529.0000 - fn: 1845.0000 - accuracy: 0.9728 - precision: 0.7405 - recall: 0.5549 - auc: 0.9276 - prc: 0.6388 - val_loss: 0.0802 - val_tp: 1746.0000 - val_fp: 328.0000 - val_tn: 69750.0000 - val_fn: 1287.0000 - val_accuracy: 0.9779 - val_precision: 0.8419 - val_recall: 0.5757 - val_auc: 0.9251 - val_prc: 0.7037
# Epoch 9/20
# 3047/3047 [==============================] - 82s 27ms/step - loss: 0.0886 - tp: 2253.0000 - fp: 757.0000 - tn: 92578.0000 - fn: 1892.0000 - accuracy: 0.9728 - precision: 0.7485 - recall: 0.5435 - auc: 0.9210 - prc: 0.6480 - val_loss: 0.0844 - val_tp: 1791.0000 - val_fp: 335.0000 - val_tn: 69743.0000 - val_fn: 1242.0000 - val_accuracy: 0.9784 - val_precision: 0.8424 - val_recall: 0.5905 - val_auc: 0.9049 - val_prc: 0.7013
# Epoch 10/20
# 3047/3047 [==============================] - 82s 27ms/step - loss: 0.0887 - tp: 2239.0000 - fp: 739.0000 - tn: 92596.0000 - fn: 1906.0000 - accuracy: 0.9729 - precision: 0.7518 - recall: 0.5402 - auc: 0.9260 - prc: 0.6463 - val_loss: 0.0852 - val_tp: 1941.0000 - val_fp: 496.0000 - val_tn: 69582.0000 - val_fn: 1092.0000 - val_accuracy: 0.9783 - val_precision: 0.7965 - val_recall: 0.6400 - val_auc: 0.9019 - val_prc: 0.6890
# Epoch 11/20
# 3047/3047 [==============================] - 82s 27ms/step - loss: 0.0890 - tp: 2252.0000 - fp: 747.0000 - tn: 92588.0000 - fn: 1893.0000 - accuracy: 0.9729 - precision: 0.7509 - recall: 0.5433 - auc: 0.9242 - prc: 0.6447 - val_loss: 0.0945 - val_tp: 1524.0000 - val_fp: 280.0000 - val_tn: 69798.0000 - val_fn: 1509.0000 - val_accuracy: 0.9755 - val_precision: 0.8448 - val_recall: 0.5025 - val_auc: 0.8992 - val_prc: 0.6765
# Epoch 12/20
# 3047/3047 [==============================] - 81s 27ms/step - loss: 0.0857 - tp: 2403.0000 - fp: 758.0000 - tn: 92577.0000 - fn: 1742.0000 - accuracy: 0.9744 - precision: 0.7602 - recall: 0.5797 - auc: 0.9263 - prc: 0.6584 - val_loss: 0.0847 - val_tp: 1783.0000 - val_fp: 384.0000 - val_tn: 69694.0000 - val_fn: 1250.0000 - val_accuracy: 0.9777 - val_precision: 0.8228 - val_recall: 0.5879 - val_auc: 0.9078 - val_prc: 0.7001
# Epoch 13/20
# 3047/3047 [==============================] - 84s 27ms/step - loss: 0.0854 - tp: 2333.0000 - fp: 745.0000 - tn: 92590.0000 - fn: 1812.0000 - accuracy: 0.9738 - precision: 0.7580 - recall: 0.5628 - auc: 0.9293 - prc: 0.6662 - val_loss: 0.0892 - val_tp: 1580.0000 - val_fp: 232.0000 - val_tn: 69846.0000 - val_fn: 1453.0000 - val_accuracy: 0.9770 - val_precision: 0.8720 - val_recall: 0.5209 - val_auc: 0.9040 - val_prc: 0.7092
# Epoch 14/20
# 3047/3047 [==============================] - 81s 27ms/step - loss: 0.0856 - tp: 2322.0000 - fp: 742.0000 - tn: 92593.0000 - fn: 1823.0000 - accuracy: 0.9737 - precision: 0.7578 - recall: 0.5602 - auc: 0.9294 - prc: 0.6625 - val_loss: 0.0829 - val_tp: 1739.0000 - val_fp: 298.0000 - val_tn: 69780.0000 - val_fn: 1294.0000 - val_accuracy: 0.9782 - val_precision: 0.8537 - val_recall: 0.5734 - val_auc: 0.9087 - val_prc: 0.7162
# Epoch 15/20
# 3047/3047 [==============================] - 83s 27ms/step - loss: 0.0840 - tp: 2351.0000 - fp: 750.0000 - tn: 92585.0000 - fn: 1794.0000 - accuracy: 0.9739 - precision: 0.7581 - recall: 0.5672 - auc: 0.9321 - prc: 0.6751 - val_loss: 0.0847 - val_tp: 1749.0000 - val_fp: 342.0000 - val_tn: 69736.0000 - val_fn: 1284.0000 - val_accuracy: 0.9778 - val_precision: 0.8364 - val_recall: 0.5767 - val_auc: 0.9063 - val_prc: 0.7136
# Epoch 16/20
# 3047/3047 [==============================] - 81s 27ms/step - loss: 0.0829 - tp: 2401.0000 - fp: 726.0000 - tn: 92609.0000 - fn: 1744.0000 - accuracy: 0.9747 - precision: 0.7678 - recall: 0.5793 - auc: 0.9333 - prc: 0.6831 - val_loss: 0.0921 - val_tp: 1559.0000 - val_fp: 229.0000 - val_tn: 69849.0000 - val_fn: 1474.0000 - val_accuracy: 0.9767 - val_precision: 0.8719 - val_recall: 0.5140 - val_auc: 0.9002 - val_prc: 0.7034
# Epoch 17/20
# 3047/3047 [==============================] - 83s 27ms/step - loss: 0.0857 - tp: 2310.0000 - fp: 718.0000 - tn: 92617.0000 - fn: 1835.0000 - accuracy: 0.9738 - precision: 0.7629 - recall: 0.5573 - auc: 0.9289 - prc: 0.6698 - val_loss: 0.0871 - val_tp: 1744.0000 - val_fp: 330.0000 - val_tn: 69748.0000 - val_fn: 1289.0000 - val_accuracy: 0.9779 - val_precision: 0.8409 - val_recall: 0.5750 - val_auc: 0.9034 - val_prc: 0.7046
# Epoch 18/20
# 3047/3047 [==============================] - 82s 27ms/step - loss: 0.0850 - tp: 2328.0000 - fp: 719.0000 - tn: 92616.0000 - fn: 1817.0000 - accuracy: 0.9740 - precision: 0.7640 - recall: 0.5616 - auc: 0.9317 - prc: 0.6675 - val_loss: 0.0834 - val_tp: 2166.0000 - val_fp: 1028.0000 - val_tn: 69050.0000 - val_fn: 867.0000 - val_accuracy: 0.9741 - val_precision: 0.6781 - val_recall: 0.7141 - val_auc: 0.9353 - val_prc: 0.7196
# Epoch 19/20
# 3047/3047 [==============================] - 84s 27ms/step - loss: 0.0828 - tp: 2420.0000 - fp: 771.0000 - tn: 92564.0000 - fn: 1725.0000 - accuracy: 0.9744 - precision: 0.7584 - recall: 0.5838 - auc: 0.9335 - prc: 0.6820 - val_loss: 0.0872 - val_tp: 1927.0000 - val_fp: 459.0000 - val_tn: 69619.0000 - val_fn: 1106.0000 - val_accuracy: 0.9786 - val_precision: 0.8076 - val_recall: 0.6353 - val_auc: 0.9022 - val_prc: 0.7006
# Epoch 20/20
# 3047/3047 [==============================] - 81s 27ms/step - loss: 0.0827 - tp: 2448.0000 - fp: 791.0000 - tn: 92544.0000 - fn: 1697.0000 - accuracy: 0.9745 - precision: 0.7558 - recall: 0.5906 - auc: 0.9343 - prc: 0.6785 - val_loss: 0.0984 - val_tp: 1183.0000 - val_fp: 171.0000 - val_tn: 69907.0000 - val_fn: 1850.0000 - val_accuracy: 0.9724 - val_precision: 0.8737 - val_recall: 0.3900 - val_auc: 0.8966 - val_prc: 0.6769

# %%
modelV0.save('LSTM_model_V0.h5')

# %%
#modelV0=tf.keras.models.load_model('aug_LSTM_model_V0.h5')

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (10, 8)
sns.set_palette("Paired")

# %%
def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(historyV0)

# %%
### create confusion matrix to summarize the actual vs. predicted labels

def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  group_names = ['TN','FP','FN','TP']
  group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
  labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
  labels = np.asarray(labels).reshape(2,2)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=labels, fmt='', cmap='Blues');
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('non_dv posts Detected (True Negatives): ', cm[0][0])
  print('non_dv posts Incorrectly Detected (False Positives): ', cm[0][1])
  print('dv posts Missed (False Negatives): ', cm[1][0])
  print('dv posts Detected (True Positives): ', cm[1][1])
  print('Total dv posts: ', np.sum(cm[1]))

# %%
train_predictions_modelV0 = modelV0.predict(X_vect_train, batch_size=32)
test_predictions_modelV0 = modelV0.predict(X_vect_test, batch_size=32)

plot_cm(y_test, test_predictions_modelV0)
# Out:
# 3047/3047 [==============================] - 22s 7ms/step
# 2285/2285 [==============================] - 15s 7ms/step
# non_dv posts Detected (True Negatives):  69807
# non_dv posts Incorrectly Detected (False Positives):  206
# dv posts Missed (False Negatives):  1936
# dv posts Detected (True Positives):  1162
# Total dv posts:  3098

# %%
predict_classes_V0=(test_predictions_modelV0 > 0.5).astype("int32")
print("modelV0 Classification report:\n\n{}".format(classification_report(y_test, predict_classes_V0)))
# Out:
# modelV0 Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     70013
#            1       0.85      0.38      0.52      3098
#
#     accuracy                           0.97     73111
#    macro avg       0.91      0.69      0.75     73111
# weighted avg       0.97      0.97      0.97     73111

# %%
# Plot the AUPRC
import sklearn
def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = sklearn.metrics.precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Precision')
    plt.ylabel('Recall')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
plot_prc("Train modelV0", y_train, train_predictions_modelV0)
plot_prc("Test modelV0", y_test, test_predictions_modelV0,linestyle='--')
plt.legend(loc='lower left');

# %% [markdown]
# ### 2. augmented dataset

# %%
aug_modelV0 = Sequential()
aug_modelV0.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X_vect_train.shape[1]))
aug_modelV0.add(SpatialDropout1D(0.6))
aug_modelV0.add(LSTM(64, dropout=0.6, recurrent_dropout=0))
aug_modelV0.add(Dense(1, activation='sigmoid'))
aug_modelV0.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=METRICS)
print(aug_modelV0.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 100)          5000000
#
#  spatial_dropout1d_1 (Spatia  (None, 500, 100)         0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,042,305
# Trainable params: 5,042,305
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
aug_historyV0 = aug_modelV0.fit(
    aug_X_vect_train, 
    aug_y_train,
    batch_size=32,
    epochs=EPOCHS,
    validation_data=(X_vect_val, y_val),
    callbacks=CALLBACKS)
# Out:
# Epoch 1/20
# 3797/3797 [==============================] - 175s 45ms/step - loss: 0.1401 - tp: 25513.0000 - fp: 2324.0000 - tn: 161083.0000 - fn: 5671.0000 - accuracy: 0.9589 - precision: 0.9165 - recall: 0.8181 - auc: 0.9713 - prc: 0.9324 - val_loss: 0.0630 - val_tp: 2367.0000 - val_fp: 811.0000 - val_tn: 69267.0000 - val_fn: 666.0000 - val_accuracy: 0.9798 - val_precision: 0.7448 - val_recall: 0.7804 - val_auc: 0.9741 - val_prc: 0.7762
# Epoch 2/20
# 3797/3797 [==============================] - 106s 28ms/step - loss: 0.1054 - tp: 25606.0000 - fp: 1823.0000 - tn: 91506.0000 - fn: 2545.0000 - accuracy: 0.9640 - precision: 0.9335 - recall: 0.9096 - auc: 0.9865 - prc: 0.9713 - val_loss: 0.0622 - val_tp: 2450.0000 - val_fp: 866.0000 - val_tn: 69212.0000 - val_fn: 583.0000 - val_accuracy: 0.9802 - val_precision: 0.7388 - val_recall: 0.8078 - val_auc: 0.9760 - val_prc: 0.8067
# Epoch 3/20
# 3797/3797 [==============================] - 103s 27ms/step - loss: 0.1021 - tp: 25716.0000 - fp: 1795.0000 - tn: 91534.0000 - fn: 2435.0000 - accuracy: 0.9652 - precision: 0.9348 - recall: 0.9135 - auc: 0.9873 - prc: 0.9729 - val_loss: 0.0560 - val_tp: 2288.0000 - val_fp: 556.0000 - val_tn: 69522.0000 - val_fn: 745.0000 - val_accuracy: 0.9822 - val_precision: 0.8045 - val_recall: 0.7544 - val_auc: 0.9730 - val_prc: 0.7905
# Epoch 4/20
# 3797/3797 [==============================] - 98s 26ms/step - loss: 0.1130 - tp: 25441.0000 - fp: 1909.0000 - tn: 91420.0000 - fn: 2710.0000 - accuracy: 0.9620 - precision: 0.9302 - recall: 0.9037 - auc: 0.9842 - prc: 0.9676 - val_loss: 0.0671 - val_tp: 2429.0000 - val_fp: 978.0000 - val_tn: 69100.0000 - val_fn: 604.0000 - val_accuracy: 0.9784 - val_precision: 0.7129 - val_recall: 0.8009 - val_auc: 0.9771 - val_prc: 0.7596
# Epoch 5/20
# 3797/3797 [==============================] - 101s 27ms/step - loss: 0.1068 - tp: 25526.0000 - fp: 1729.0000 - tn: 91600.0000 - fn: 2625.0000 - accuracy: 0.9642 - precision: 0.9366 - recall: 0.9068 - auc: 0.9857 - prc: 0.9703 - val_loss: 0.0611 - val_tp: 2142.0000 - val_fp: 496.0000 - val_tn: 69582.0000 - val_fn: 891.0000 - val_accuracy: 0.9810 - val_precision: 0.8120 - val_recall: 0.7062 - val_auc: 0.9677 - val_prc: 0.7603
# Epoch 6/20
# 3797/3797 [==============================] - 99s 26ms/step - loss: 0.1072 - tp: 25538.0000 - fp: 1778.0000 - tn: 91551.0000 - fn: 2613.0000 - accuracy: 0.9639 - precision: 0.9349 - recall: 0.9072 - auc: 0.9862 - prc: 0.9704 - val_loss: 0.0588 - val_tp: 2166.0000 - val_fp: 517.0000 - val_tn: 69561.0000 - val_fn: 867.0000 - val_accuracy: 0.9811 - val_precision: 0.8073 - val_recall: 0.7141 - val_auc: 0.9730 - val_prc: 0.7714
# Epoch 7/20
# 3797/3797 [==============================] - ETA: 0s - loss: 0.1087 - tp: 25610.0000 - fp: 1894.0000 - tn: 91435.0000 - fn: 2541.0000 - accuracy: 0.9635 - precision: 0.9311 - recall: 0.9097 - auc: 0.9856 - prc: 0.9695Restoring model weights from the end of the best epoch: 2.
# 3797/3797 [==============================] - 97s 25ms/step - loss: 0.1087 - tp: 25610.0000 - fp: 1894.0000 - tn: 91435.0000 - fn: 2541.0000 - accuracy: 0.9635 - precision: 0.9311 - recall: 0.9097 - auc: 0.9856 - prc: 0.9695 - val_loss: 0.0613 - val_tp: 2371.0000 - val_fp: 875.0000 - val_tn: 69203.0000 - val_fn: 662.0000 - val_accuracy: 0.9790 - val_precision: 0.7304 - val_recall: 0.7817 - val_auc: 0.9787 - val_prc: 0.7925
# Epoch 7: early stopping

# %%
aug_modelV0.save('aug_modelV0.h5')

# %%
plot_metrics(aug_historyV0)

# %%
test_predictions_aug_modelV0 = aug_modelV0.predict(X_vect_test, batch_size=32)
aug_predict_classes_V0=(test_predictions_aug_modelV0 > 0.5).astype("int32")
print("modelV0 Classification report:\n\n{}".format(classification_report(y_test, predict_classes_V0)))
# Out:
# 2285/2285 [==============================] - 17s 7ms/step
# modelV0 Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     70013
#            1       0.85      0.38      0.52      3098
#
#     accuracy                           0.97     73111
#    macro avg       0.91      0.69      0.75     73111
# weighted avg       0.97      0.97      0.97     73111

# %%
plot_prc("augmented model", y_test, test_predictions_aug_modelV0)
plot_prc("non-aumented model", y_test, test_predictions_modelV0,linestyle='--')
plt.legend(loc='lower left');

# %% [markdown]
# ### 3. undersampling method with augmented data

# %%
# Class count
count_class_0, count_class_1 = aug_train_data.Class.value_counts()

# Divide by class
df_class_0 = aug_train_data[aug_train_data['Class'] == 0]
df_class_1 = aug_train_data[aug_train_data['Class'] == 1]
count_class_0, count_class_1
# Out:
# (93329, 28151)

# %%
df_class_0_under = df_class_0.sample(count_class_1)
df_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_under.Class.value_counts())
# Out:
# Random under-sampling:
# 0    28151
# 1    28151
# Name: Class, dtype: int64

# %%
X_train_under=df_under['all_text']
y_train_under = df_under.Class

X_train_under.shape, y_train_under.shape
# Out:
# ((56302,), (56302,))

# %%
X_vect_train_under = tokenizer.texts_to_sequences(X_train_under.values)
X_vect_train_under = pad_sequences(X_vect_train_under, maxlen=MAX_SEQUENCE_LENGTH)

# %%
METRICS = [
    keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

CALLBACKS=[EarlyStopping(monitor='val_prc', verbose=1,patience=3, mode='max',restore_best_weights=True)]

EPOCHS = 20

# %%
aug_modelV1 = Sequential()
aug_modelV1.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X_vect_train.shape[1]))
aug_modelV1.add(SpatialDropout1D(0.4))
aug_modelV1.add(LSTM(64, dropout=0.4, recurrent_dropout=0))
aug_modelV1.add(Dense(4, activation='relu'))
aug_modelV1.add(Dense(1, activation='sigmoid'))
aug_modelV1.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=METRICS)
print(aug_modelV1.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 500, 100)          5000000
#
#  spatial_dropout1d_2 (Spatia  (None, 500, 100)         0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  dense_2 (Dense)             (None, 4)                 260
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 5,042,505
# Trainable params: 5,042,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
aug_historyV1 = aug_modelV1.fit(
    X_vect_train_under, 
    y_train_under,
    batch_size=32,
    epochs=EPOCHS,
    validation_data=(X_vect_val, y_val),
    callbacks=CALLBACKS)
# Out:
# Epoch 1/20
# 1760/1760 [==============================] - 119s 65ms/step - loss: 0.1628 - tp: 26169.0000 - fp: 1609.0000 - tn: 26542.0000 - fn: 1982.0000 - accuracy: 0.9362 - precision: 0.9421 - recall: 0.9296 - auc: 0.9832 - prc: 0.9846 - val_loss: 0.0877 - val_tp: 2800.0000 - val_fp: 2307.0000 - val_tn: 67771.0000 - val_fn: 233.0000 - val_accuracy: 0.9653 - val_precision: 0.5483 - val_recall: 0.9232 - val_auc: 0.9868 - val_prc: 0.8219
# Epoch 2/20
# 1760/1760 [==============================] - 65s 37ms/step - loss: 0.0754 - tp: 27342.0000 - fp: 696.0000 - tn: 27455.0000 - fn: 809.0000 - accuracy: 0.9733 - precision: 0.9752 - recall: 0.9713 - auc: 0.9958 - prc: 0.9959 - val_loss: 0.0850 - val_tp: 2816.0000 - val_fp: 1753.0000 - val_tn: 68325.0000 - val_fn: 217.0000 - val_accuracy: 0.9731 - val_precision: 0.6163 - val_recall: 0.9285 - val_auc: 0.9899 - val_prc: 0.8544
# Epoch 3/20
# 1760/1760 [==============================] - 63s 36ms/step - loss: 0.0631 - tp: 27503.0000 - fp: 574.0000 - tn: 27577.0000 - fn: 648.0000 - accuracy: 0.9783 - precision: 0.9796 - recall: 0.9770 - auc: 0.9967 - prc: 0.9966 - val_loss: 0.0586 - val_tp: 2767.0000 - val_fp: 1194.0000 - val_tn: 68884.0000 - val_fn: 266.0000 - val_accuracy: 0.9800 - val_precision: 0.6986 - val_recall: 0.9123 - val_auc: 0.9877 - val_prc: 0.8653
# Epoch 4/20
# 1760/1760 [==============================] - 59s 34ms/step - loss: 0.0621 - tp: 27571.0000 - fp: 606.0000 - tn: 27545.0000 - fn: 580.0000 - accuracy: 0.9789 - precision: 0.9785 - recall: 0.9794 - auc: 0.9969 - prc: 0.9966 - val_loss: 0.0704 - val_tp: 2815.0000 - val_fp: 1532.0000 - val_tn: 68546.0000 - val_fn: 218.0000 - val_accuracy: 0.9761 - val_precision: 0.6476 - val_recall: 0.9281 - val_auc: 0.9893 - val_prc: 0.8722
# Epoch 5/20
# 1760/1760 [==============================] - 61s 34ms/step - loss: 0.0593 - tp: 27571.0000 - fp: 540.0000 - tn: 27611.0000 - fn: 580.0000 - accuracy: 0.9801 - precision: 0.9808 - recall: 0.9794 - auc: 0.9971 - prc: 0.9970 - val_loss: 0.0713 - val_tp: 2759.0000 - val_fp: 1222.0000 - val_tn: 68856.0000 - val_fn: 274.0000 - val_accuracy: 0.9795 - val_precision: 0.6930 - val_recall: 0.9097 - val_auc: 0.9872 - val_prc: 0.8494
# Epoch 6/20
# 1760/1760 [==============================] - 56s 32ms/step - loss: 0.0583 - tp: 27563.0000 - fp: 517.0000 - tn: 27634.0000 - fn: 588.0000 - accuracy: 0.9804 - precision: 0.9816 - recall: 0.9791 - auc: 0.9971 - prc: 0.9968 - val_loss: 0.0670 - val_tp: 2687.0000 - val_fp: 1064.0000 - val_tn: 69014.0000 - val_fn: 346.0000 - val_accuracy: 0.9807 - val_precision: 0.7163 - val_recall: 0.8859 - val_auc: 0.9835 - val_prc: 0.8457
# Epoch 7/20
# 1760/1760 [==============================] - ETA: 0s - loss: 0.0593 - tp: 27546.0000 - fp: 516.0000 - tn: 27635.0000 - fn: 605.0000 - accuracy: 0.9801 - precision: 0.9816 - recall: 0.9785 - auc: 0.9971 - prc: 0.9968Restoring model weights from the end of the best epoch: 4.
# 1760/1760 [==============================] - 59s 34ms/step - loss: 0.0593 - tp: 27546.0000 - fp: 516.0000 - tn: 27635.0000 - fn: 605.0000 - accuracy: 0.9801 - precision: 0.9816 - recall: 0.9785 - auc: 0.9971 - prc: 0.9968 - val_loss: 0.0525 - val_tp: 2642.0000 - val_fp: 851.0000 - val_tn: 69227.0000 - val_fn: 391.0000 - val_accuracy: 0.9830 - val_precision: 0.7564 - val_recall: 0.8711 - val_auc: 0.9869 - val_prc: 0.8651
# Epoch 7: early stopping

# %%
plot_metrics(aug_historyV1)

# %%
test_predictions_modelV1 = aug_modelV1.predict(X_vect_test, batch_size=32)
predict_classes_V1=(test_predictions_modelV1 > 0.5).astype("int32")
print("ModelV1 Classification report:\n\n{}".format(classification_report(y_test, predict_classes_V1)))
# Out:
# 2285/2285 [==============================] - 16s 7ms/step
# ModelV1 Classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     70013
#            1       0.65      0.92      0.77      3098
#
#     accuracy                           0.98     73111
#    macro avg       0.83      0.95      0.88     73111
# weighted avg       0.98      0.98      0.98     73111

# %%
predict_classes_V1_40=(test_predictions_modelV1 > 0.4).astype("int32")
print(classification_report(y_test,predict_classes_V1_40))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     70013
#            1       0.62      0.94      0.74      3098
#
#     accuracy                           0.97     73111
#    macro avg       0.81      0.96      0.86     73111
# weighted avg       0.98      0.97      0.98     73111

# %%
predict_classes_V1_90=(test_predictions_modelV1 > 0.9).astype("int32")
print(classification_report(y_test,predict_classes_V1_90))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.82      0.82      0.82      3098
#
#     accuracy                           0.98     73111
#    macro avg       0.91      0.91      0.91     73111
# weighted avg       0.98      0.98      0.98     73111

# %%
predict_classes_V1_80=(test_predictions_modelV1 > 0.8).astype("int32")
print(classification_report(y_test,predict_classes_V1_80))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.77      0.87      0.82      3098
#
#     accuracy                           0.98     73111
#    macro avg       0.88      0.93      0.90     73111
# weighted avg       0.98      0.98      0.98     73111

# %%
predict_classes_V1_70=(test_predictions_modelV1 > 0.7).astype("int32")
print(classification_report(y_test,predict_classes_V1_70))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     70013
#            1       0.73      0.89      0.80      3098
#
#     accuracy                           0.98     73111
#    macro avg       0.86      0.94      0.90     73111
# weighted avg       0.98      0.98      0.98     73111

# %%
modelV1.save('aug_LSTM_model_V1.h5')

# %% [markdown]
# ### 4.  undersampling using augmented dataset with example weight

# %%
example_weight=count_class_0/ count_class_1
example_weight
# Out:
# 3.315299634116017

# %%
EXAMPLE_WEIGHT= {0: example_weight, 1: 1}

# %%
aug_modelV2 = Sequential()
aug_modelV2.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X_vect_train.shape[1]))
aug_modelV2.add(SpatialDropout1D(0.4))
aug_modelV2.add(LSTM(64, dropout=0.4, recurrent_dropout=0))
aug_modelV2.add(Dense(4, activation='relu'))
aug_modelV2.add(Dense(1, activation='sigmoid'))
aug_modelV2.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=METRICS)
print(aug_modelV2.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 500, 100)          5000000
#
#  spatial_dropout1d_4 (Spatia  (None, 500, 100)         0
#  lDropout1D)
#
#  lstm_4 (LSTM)               (None, 64)                42240
#
#  dense_6 (Dense)             (None, 4)                 260
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 5,042,505
# Trainable params: 5,042,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
CALLBACKS=[EarlyStopping(monitor='val_prc', verbose=1,patience=5, mode='max',restore_best_weights=True)]

aug_historyV2 = aug_modelV2.fit(
    X_vect_train_under, 
    y_train_under,
    batch_size=32,
    epochs=EPOCHS,
    class_weight=EXAMPLE_WEIGHT,
    validation_data=(X_vect_val, y_val),
    callbacks=CALLBACKS)
# Out:
# Epoch 1/20
# 1760/1760 [==============================] - 117s 64ms/step - loss: 0.3050 - tp: 36599.0000 - fp: 859.0000 - tn: 41054.0000 - fn: 5278.0000 - accuracy: 0.9268 - precision: 0.9771 - recall: 0.8740 - auc: 0.9868 - prc: 0.9879 - val_loss: 0.0608 - val_tp: 2489.0000 - val_fp: 978.0000 - val_tn: 69100.0000 - val_fn: 544.0000 - val_accuracy: 0.9792 - val_precision: 0.7179 - val_recall: 0.8206 - val_auc: 0.9798 - val_prc: 0.7979
# Epoch 2/20
# 1760/1760 [==============================] - 64s 37ms/step - loss: 0.1484 - tp: 26566.0000 - fp: 413.0000 - tn: 27738.0000 - fn: 1585.0000 - accuracy: 0.9645 - precision: 0.9847 - recall: 0.9437 - auc: 0.9946 - prc: 0.9952 - val_loss: 0.0457 - val_tp: 2626.0000 - val_fp: 800.0000 - val_tn: 69278.0000 - val_fn: 407.0000 - val_accuracy: 0.9835 - val_precision: 0.7665 - val_recall: 0.8658 - val_auc: 0.9854 - val_prc: 0.8625
# Epoch 3/20
# 1760/1760 [==============================] - 60s 34ms/step - loss: 0.1183 - tp: 26996.0000 - fp: 369.0000 - tn: 27782.0000 - fn: 1155.0000 - accuracy: 0.9729 - precision: 0.9865 - recall: 0.9590 - auc: 0.9963 - prc: 0.9966 - val_loss: 0.0578 - val_tp: 2698.0000 - val_fp: 1296.0000 - val_tn: 68782.0000 - val_fn: 335.0000 - val_accuracy: 0.9777 - val_precision: 0.6755 - val_recall: 0.8895 - val_auc: 0.9883 - val_prc: 0.8668
# Epoch 4/20
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.1087 - tp: 27112.0000 - fp: 313.0000 - tn: 27838.0000 - fn: 1039.0000 - accuracy: 0.9760 - precision: 0.9886 - recall: 0.9631 - auc: 0.9966 - prc: 0.9969 - val_loss: 0.0421 - val_tp: 2532.0000 - val_fp: 541.0000 - val_tn: 69537.0000 - val_fn: 501.0000 - val_accuracy: 0.9857 - val_precision: 0.8240 - val_recall: 0.8348 - val_auc: 0.9829 - val_prc: 0.8705
# Epoch 5/20
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.0980 - tp: 27167.0000 - fp: 271.0000 - tn: 27880.0000 - fn: 984.0000 - accuracy: 0.9777 - precision: 0.9901 - recall: 0.9650 - auc: 0.9971 - prc: 0.9975 - val_loss: 0.0508 - val_tp: 2678.0000 - val_fp: 831.0000 - val_tn: 69247.0000 - val_fn: 355.0000 - val_accuracy: 0.9838 - val_precision: 0.7632 - val_recall: 0.8830 - val_auc: 0.9827 - val_prc: 0.8630
# Epoch 6/20
# 1760/1760 [==============================] - 57s 33ms/step - loss: 0.1001 - tp: 27170.0000 - fp: 278.0000 - tn: 27873.0000 - fn: 981.0000 - accuracy: 0.9776 - precision: 0.9899 - recall: 0.9652 - auc: 0.9970 - prc: 0.9973 - val_loss: 0.0448 - val_tp: 2651.0000 - val_fp: 740.0000 - val_tn: 69338.0000 - val_fn: 382.0000 - val_accuracy: 0.9847 - val_precision: 0.7818 - val_recall: 0.8741 - val_auc: 0.9900 - val_prc: 0.8677
# Epoch 7/20
# 1760/1760 [==============================] - 56s 32ms/step - loss: 0.0932 - tp: 27152.0000 - fp: 243.0000 - tn: 27908.0000 - fn: 999.0000 - accuracy: 0.9779 - precision: 0.9911 - recall: 0.9645 - auc: 0.9974 - prc: 0.9976 - val_loss: 0.0495 - val_tp: 2692.0000 - val_fp: 852.0000 - val_tn: 69226.0000 - val_fn: 341.0000 - val_accuracy: 0.9837 - val_precision: 0.7596 - val_recall: 0.8876 - val_auc: 0.9893 - val_prc: 0.8635
# Epoch 8/20
# 1760/1760 [==============================] - 56s 32ms/step - loss: 0.0912 - tp: 27248.0000 - fp: 239.0000 - tn: 27912.0000 - fn: 903.0000 - accuracy: 0.9797 - precision: 0.9913 - recall: 0.9679 - auc: 0.9975 - prc: 0.9977 - val_loss: 0.0462 - val_tp: 2668.0000 - val_fp: 735.0000 - val_tn: 69343.0000 - val_fn: 365.0000 - val_accuracy: 0.9850 - val_precision: 0.7840 - val_recall: 0.8797 - val_auc: 0.9878 - val_prc: 0.8761
# Epoch 9/20
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.0845 - tp: 27292.0000 - fp: 231.0000 - tn: 27920.0000 - fn: 859.0000 - accuracy: 0.9806 - precision: 0.9916 - recall: 0.9695 - auc: 0.9976 - prc: 0.9978 - val_loss: 0.0474 - val_tp: 2674.0000 - val_fp: 721.0000 - val_tn: 69357.0000 - val_fn: 359.0000 - val_accuracy: 0.9852 - val_precision: 0.7876 - val_recall: 0.8816 - val_auc: 0.9814 - val_prc: 0.8702
# Epoch 10/20
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.0851 - tp: 27277.0000 - fp: 217.0000 - tn: 27934.0000 - fn: 874.0000 - accuracy: 0.9806 - precision: 0.9921 - recall: 0.9690 - auc: 0.9977 - prc: 0.9979 - val_loss: 0.0477 - val_tp: 2694.0000 - val_fp: 785.0000 - val_tn: 69293.0000 - val_fn: 339.0000 - val_accuracy: 0.9846 - val_precision: 0.7744 - val_recall: 0.8882 - val_auc: 0.9846 - val_prc: 0.8749
# Epoch 11/20
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.0858 - tp: 27246.0000 - fp: 226.0000 - tn: 27925.0000 - fn: 905.0000 - accuracy: 0.9799 - precision: 0.9918 - recall: 0.9679 - auc: 0.9975 - prc: 0.9979 - val_loss: 0.0473 - val_tp: 2670.0000 - val_fp: 654.0000 - val_tn: 69424.0000 - val_fn: 363.0000 - val_accuracy: 0.9861 - val_precision: 0.8032 - val_recall: 0.8803 - val_auc: 0.9879 - val_prc: 0.8724
# Epoch 12/20
# 1760/1760 [==============================] - 56s 32ms/step - loss: 0.0889 - tp: 27159.0000 - fp: 219.0000 - tn: 27932.0000 - fn: 992.0000 - accuracy: 0.9785 - precision: 0.9920 - recall: 0.9648 - auc: 0.9976 - prc: 0.9978 - val_loss: 0.0553 - val_tp: 2728.0000 - val_fp: 971.0000 - val_tn: 69107.0000 - val_fn: 305.0000 - val_accuracy: 0.9825 - val_precision: 0.7375 - val_recall: 0.8994 - val_auc: 0.9859 - val_prc: 0.8512
# Epoch 13/20
# 1760/1760 [==============================] - ETA: 0s - loss: 0.0861 - tp: 27302.0000 - fp: 232.0000 - tn: 27919.0000 - fn: 849.0000 - accuracy: 0.9808 - precision: 0.9916 - recall: 0.9698 - auc: 0.9978 - prc: 0.9979Restoring model weights from the end of the best epoch: 8.
# 1760/1760 [==============================] - 58s 33ms/step - loss: 0.0861 - tp: 27302.0000 - fp: 232.0000 - tn: 27919.0000 - fn: 849.0000 - accuracy: 0.9808 - precision: 0.9916 - recall: 0.9698 - auc: 0.9978 - prc: 0.9979 - val_loss: 0.0470 - val_tp: 2646.0000 - val_fp: 736.0000 - val_tn: 69342.0000 - val_fn: 387.0000 - val_accuracy: 0.9846 - val_precision: 0.7824 - val_recall: 0.8724 - val_auc: 0.9826 - val_prc: 0.8565
# Epoch 13: early stopping

# %%
plot_metrics(aug_historyV2)

# %%
test_predictions_modelV2 = aug_modelV2.predict(X_vect_test, batch_size=32)
predict_classes_V2=(test_predictions_modelV2 > 0.5).astype("int32")
print("ModelV1 Classification report:\n\n{}".format(classification_report(y_test, predict_classes_V2)))
# Out:
# 2285/2285 [==============================] - 19s 8ms/step
# ModelV1 Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.79      0.88      0.83      3098
#
#     accuracy                           0.99     73111
#    macro avg       0.89      0.93      0.91     73111
# weighted avg       0.99      0.99      0.99     73111

# %%
predict_classes_V2_90=(test_predictions_modelV2 > 0.9).astype("int32")
print(classification_report(y_test,predict_classes_V2_90))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     70013
#            1       0.87      0.76      0.81      3098
#
#     accuracy                           0.99     73111
#    macro avg       0.93      0.88      0.90     73111
# weighted avg       0.98      0.99      0.98     73111

# %%
predict_classes_V2_40=(test_predictions_modelV2 > 0.4).astype("int32")
print(classification_report(y_test,predict_classes_V2_40))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.77      0.89      0.83      3098
#
#     accuracy                           0.98     73111
#    macro avg       0.88      0.94      0.91     73111
# weighted avg       0.99      0.98      0.98     73111

# %%
predict_classes_V2_80=(test_predictions_modelV2 > 0.8).astype("int32")
print(classification_report(y_test,predict_classes_V2_80))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.84      0.81      0.83      3098
#
#     accuracy                           0.99     73111
#    macro avg       0.92      0.90      0.91     73111
# weighted avg       0.99      0.99      0.99     73111

# %%
predict_classes_V2_85=(test_predictions_modelV2 > 0.85).astype("int32")
print(classification_report(y_test,predict_classes_V2_85))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     70013
#            1       0.86      0.80      0.83      3098
#
#     accuracy                           0.99     73111
#    macro avg       0.92      0.90      0.91     73111
# weighted avg       0.99      0.99      0.99     73111

# %%
plot_prc("Augmented-undersampling-example weight", y_test, test_predictions_modelV2)
plot_prc("Augmented-undersampling", y_test, test_predictions_modelV1)
plot_prc("Unaugmented", y_test, test_predictions_modelV0)
plot_prc("Augmented", y_test, test_predictions_aug_modelV0)
plt.legend(loc='lower left')
plt.title('PRC comparison')
# Out:
# Text(0.5, 1.0, 'PRC comparison')

# %%
modelV2.save('aug_LSTM_model_V2.h5')
